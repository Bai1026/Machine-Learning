# %% [markdown]
# # **Homework 10 - Adversarial Attack**

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# !nvidia-smi
# Out:
# Sat May 27 03:18:24 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090         Off| 00000000:01:00.0 Off |                  Off |
# |  0%   47C    P8               37W / 480W|      6MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   2331254      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %%
# set up environment
# !pip install pytorchcv
# !pip install imgaug

# download
# !gdown --id 1t2UFQXr1cr5qLMBK2oN2rY1NDypi9Nyw --output data.zip

# if the above link isn't available, try this one
# !wget https://www.dropbox.com/s/lbpypqamqjpt2qz/data.zip

# unzip
# !unzip ./data.zip
# Out:
# Requirement already satisfied: pytorchcv in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (0.0.67)
# Requirement already satisfied: numpy in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from pytorchcv) (1.24.3)
# Requirement already satisfied: requests in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from pytorchcv) (2.29.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from requests->pytorchcv) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wmnlab/.local/lib/python3.10/site-packages (from requests->pytorchcv) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from requests->pytorchcv) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from requests->pytorchcv) (3.4)
# Requirement already satisfied: imgaug in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (0.20.0)
# Requirement already satisfied: six in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: matplotlib in /home/wmnlab/.local/lib/python3.10/site-packages (from imgaug) (3.7.1)
# Requirement already satisfied: Shapely in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (2.0.1)
# Requirement already satisfied: Pillow in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (9.4.0)
# Requirement already satisfied: imageio in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (2.29.0)
# Requirement already satisfied: numpy>=1.15 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (1.24.3)
# Requirement already satisfied: opencv-python in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from imgaug) (4.7.0.72)
# Requirement already satisfied: scipy in /home/wmnlab/.local/lib/python3.10/site-packages (from imgaug) (1.10.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (0.2)
# Requirement already satisfied: packaging>=20.0 in /home/wmnlab/.local/lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (23.0)
# Requirement already satisfied: networkx>=2.8 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (2023.4.12)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wmnlab/.local/lib/python3.10/site-packages (from matplotlib->imgaug) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/wmnlab/.local/lib/python3.10/site-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/wmnlab/.local/lib/python3.10/site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/wmnlab/anaconda3/envs/sheng-ru/lib/python3.10/site-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/wmnlab/.local/lib/python3.10/site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wmnlab/.local/lib/python3.10/site-packages (from matplotlib->imgaug) (4.39.0)

# %%
# !rm ./data.zip

# %%
import torch
import torch.nn as nn
from pytorchcv.model_provider import get_model as ptcv_get_model
import random
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 8

def same_seeds(seed):
	  torch.manual_seed(seed)
	  if torch.cuda.is_available():
		    torch.cuda.manual_seed(seed)
		    torch.cuda.manual_seed_all(seed)
	  np.random.seed(seed)
	  random.seed(seed)
	  torch.backends.cudnn.benchmark = False
	  torch.backends.cudnn.deterministic = True
same_seeds(5269)

# %% [markdown]
# ## Global Settings
# #### **[NOTE]**: Don't change the settings here, or your generated image might not meet the constraint.
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

# do not change the epsilon
epsilon = 8/255/std

# %%
root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

# do not add transform -> exceed the memory
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    grad = x_adv.grad.detach()
    x_adv = x_adv + epsilon * grad.sign()
    return x_adv

################ TODO: Medium baseline #######################
# reference: https://blog.csdn.net/weixin_42369818/article/details/125604940 
# alpha and num_iter can be decided by yourself
alpha = 0.8/255/std

def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    x_adv = x
    
    for i in range(num_iter):
        x_adv = x_adv.detach().clone() # initialize x_adv as original benign image x
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        # fgsm: use gradient ascent on x_adv to maximize loss
        grad = x_adv.grad.detach()
        
        # just add the below codes
        x_adv = x_adv + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon)
    return x_adv

################ TODO: Strong baseline ####################
def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20, decay=0.3):
    x_adv = x
    # initialze momentum tensor
    momentum = torch.zeros_like(x).detach().to(device)

    for i in range(num_iter):
        x_adv = x_adv.detach().clone()
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        
        # TODO: Refer to the algorithm of MI-FGSM
        grad = x_adv.grad.detach()
        grad = decay * momentum + grad/(grad.abs().sum() + 1e-8)
        
        momentum = grad
        x_adv = x_adv + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv

# %% [markdown]
# ## Utils -- Attack
# * Recall
#   * ToTensor() can be seen as a function where $T(x) = x/255$.
#   * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#   * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#   * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#   * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#   * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Other kinds of models are prohibited, and it will be considered to be cheating if you use them.
#
# Note: Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
# This function is used to check whether you use models pretrained on cifar10 instead of other datasets
def model_checker(model_name):
  assert ('cifar10' in model_name) and ('cifar100' not in model_name), 'The model selected is not pretrained on cifar10!'

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

# change the model here
model_name = 'resnet110_cifar10'
model_checker(model_name)

model = ptcv_get_model(model_name, pretrained=True).to(device)
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.95000, benign_loss = 0.22690

# %% [markdown]
# ## FGSM

# %%
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)
# Out:
# fgsm_acc = 0.59000, fgsm_loss = 2.48091

# %% [markdown]
# ## I-FGSM
# > same as above

# %%
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(model, adv_loader, ifgsm, loss_fn)
print(f'ifgsm_acc = {ifgsm_acc:.5f}, ifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'ifgsm', adv_examples, adv_names)
# Out:
# ifgsm_acc = 0.01000, ifgsm_loss = 17.42788

# %% [markdown]
# ## MI-FGSM
# > same as above

# %%
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(model, adv_loader, mifgsm, loss_fn)
print(f'mifgsm_acc = {ifgsm_acc:.5f}, mifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'mifgsm', adv_examples, adv_names)
# Out:
# mifgsm_acc = 0.00000, mifgsm_loss = 18.53377

# %% [markdown]
# ## Compression

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd ifgsm
# !tar zcvf ../ifgsm.tgz *
# %cd ..

# %cd mifgsm
# !tar zcvf ../mifgsm.tgz *
# %cd ..

# %% [markdown]
# ## Example of Ensemble Attack
# * Ensemble multiple models as your proxy model to increase the black-box transferability ([paper](https://arxiv.org/abs/1611.02770))
# * Reference: https://blog.csdn.net/weixin_42369818/article/details/125604940

# %%
# !git clone https://github.com/kuangliu/pytorch-cifar.git
# Out:
# fatal: destination path 'pytorch-cifar' already exists and is not an empty directory.

# %%
# cd pytorch-cifar
# !cd ..
# %cd ..
# %ls
# %pwd

# %%
# !cp pytorch-cifar/models/resnet.py resnet.py

# %%
from resnet import ResNet18
undertrain_resnet18 = ResNet18().cuda()

# %% [markdown]
# ## Ensemble

# %%
################ BOSS BASELINE ######################

class ensembleNet(nn.Module):
    def __init__(self, model_names):
        super().__init__()
        self.models = nn.ModuleList([ptcv_get_model(name, pretrained=True) for name in model_names])
        self.models.append(undertrain_resnet18) 

    def forward(self, x):
        #################### TODO: boss baseline ###################
        # reference: chatGPT
        
        ensemble_logits = None
        for i, m in enumerate(self.models):
          if i == 0:
            ensemble_logits = m(x)
          else:
            ensemble_logits += m(x)
          
        # TODO: sum up logits from multiple models -> then do the average
        return ensemble_logits/len(self.models)

# %% [markdown]
# * Construct your ensemble model

# %%
model_names = [
    'nin_cifar10',
    'resnet20_cifar10',
    'resnet56_cifar10',
    'preresnet56_cifar10',
    'preresnet272bn_cifar10',
    'seresnet110_cifar10',
    'pyramidnet110_a84_cifar10',
    # 'pyramidnet200_a240_bn_cifar10'
    'pyramidnet110_a270_cifar10',
    'densenet40_k12_bc_cifar10',
    'wrn40_8_cifar10',
    'xdensenet40_2_k24_bc_cifar10',
    'xdensenet40_2_k36_bc_cifar10',
    
    'wrn28_10_cifar10',
    'wrn20_10_1bit_cifar10',
    'ror3_56_cifar10',
    'ror3_164_cifar10',
    'wrn20_10_32bit_cifar10',
    'rir_cifar10',
    'sepreresnet110_cifar10',
    'seresnet272bn_cifar10',
    'resnext272_2x32d_cifar10',
    'seresnet542bn_cifar10',
    'shakeshakeresnet20_2x16d_cifar10',
    'shakeshakeresnet26_2x32d_cifar10',
    'diaresnet56_cifar10',
    'diaresnet164bn_cifar10',
    'diaresnet110_cifar10',
    'diapreresnet20_cifar10',
    'diapreresnet164bn_cifar10',
    'preresnet20_cifar10'
    
    # models that are forbidden
    # 'diapreresnet1202_cifar10',
    # 'msdnet22_cifar10',
    # 'diaresnet1001_cifar10',
    # 'diaresnet1202_cifar10','
    # 'resnext20_32x4d_cifar10',
    # 'shakedropresnet20_cifar10',
    # 'resdropresnet20_cifar10',
    # 'fractalnet_cifar10',
    # 'seresnet1001_cifar10',
    # 'sepreresnet164bn_cifar10',
    # 'sepreresnet1001_cifar10',
    # 'msdnet22_cifar10',
]

for model_name in model_names:
  model_checker(model_name)

ensemble_model = ensembleNet(model_names).to(device)
ensemble_model.eval()
# Out:
# ensembleNet(
#   (models): ModuleList(
#     (0): CIFARNIN(
#       (features): Sequential(
#         (stage1): Sequential(
#           (unit1): NINConv(
#             (conv): Conv2d(3, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 160, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): NINConv(
#             (conv): Conv2d(160, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (pool2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (dropout2): Dropout(p=0.5, inplace=False)
#           (unit1): NINConv(
#             (conv): Conv2d(96, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (pool3): AvgPool2d(kernel_size=3, stride=2, padding=1)
#           (dropout3): Dropout(p=0.5, inplace=False)
#           (unit1): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#       )
#       (output): Sequential(
#         (final_conv): NINConv(
#           (conv): Conv2d(192, 10, kernel_size=(1, 1), stride=(1, 1))
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#     )
#     (1): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (2): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (3): CIFARPreResNet(
#       (features): Sequential(
#         (init_block): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (stage1): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit4): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit5): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit6): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit7): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit8): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit9): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (stage2): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#             (identity_conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit4): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit5): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit6): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit7): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit8): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit9): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (stage3): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#             (identity_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit4): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit5): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit6): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit7): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit8): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit9): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (4): CIFARPreResNet(
#       (features): Sequential(
# ...
#                     (activ): ReLU(inplace=True)
#                     (fc2): Linear(in_features=64, out_features=1024, bias=True)
#                   )
#                 )
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (unit17): DIAPreResUnit(
#             (body): PreResBottleneck(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv3): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#             )
#             (attention): DIAAttention(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (lstm): DIALSTMCell(
#                 (x_amps): Sequential(
#                   (amp1): FirstLSTMAmp(
#                     (fc1): Linear(in_features=256, out_features=64, bias=True)
#                     (activ): ReLU(inplace=True)
#                     (fc2): Linear(in_features=64, out_features=1024, bias=True)
#                   )
#                 )
#                 (h_amps): Sequential(
#                   (amp1): FirstLSTMAmp(
#                     (fc1): Linear(in_features=256, out_features=64, bias=True)
#                     (activ): ReLU(inplace=True)
#                     (fc2): Linear(in_features=64, out_features=1024, bias=True)
#                   )
#                 )
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (unit18): DIAPreResUnit(
#             (body): PreResBottleneck(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv3): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#             )
#             (attention): DIAAttention(
#               (pool): AdaptiveAvgPool2d(output_size=1)
#               (lstm): DIALSTMCell(
#                 (x_amps): Sequential(
#                   (amp1): FirstLSTMAmp(
#                     (fc1): Linear(in_features=256, out_features=64, bias=True)
#                     (activ): ReLU(inplace=True)
#                     (fc2): Linear(in_features=64, out_features=1024, bias=True)
#                   )
#                 )
#                 (h_amps): Sequential(
#                   (amp1): FirstLSTMAmp(
#                     (fc1): Linear(in_features=256, out_features=64, bias=True)
#                     (activ): ReLU(inplace=True)
#                     (fc2): Linear(in_features=64, out_features=1024, bias=True)
#                   )
#                 )
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=256, out_features=10, bias=True)
#     )
#     (29): CIFARPreResNet(
#       (features): Sequential(
#         (init_block): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (stage1): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (stage2): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#             (identity_conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (stage3): Sequential(
#           (unit1): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#             (identity_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (unit2): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (unit3): PreResUnit(
#             (body): PreResBlock(
#               (conv1): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (conv2): PreConvBlock(
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (30): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential()
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential()
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential()
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential()
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (shortcut): Sequential()
#         )
#       )
#       (linear): Linear(in_features=512, out_features=10, bias=True)
#     )
#   )
# )

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

benign_acc, benign_loss = epoch_benign(ensemble_model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.98000, benign_loss = 0.09543

# %%
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(ensemble_model, adv_loader, mifgsm, loss_fn)
print(f'ensemble_mifgsm_acc = {ifgsm_acc:.5f}, ensemble_mifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'ensemble_mifgsm', adv_examples, adv_names)
# Out:
# ensemble_mifgsm_acc = 0.00500, ensemble_mifgsm_loss = 13.73858

# %%
# %cd ensemble_ifgsm
# !tar zcvf ../ensemble_ifgsm.tgz *
# %cd ..

# %cd ensemble_mifgsm
# !tar zcvf ../ensemble_mifgsm.tgz *
# %cd ..

# %pwd
# %cd ensemble_dmifgsm
# !tar zcvf ../ensemble_dmifgsm.tgz *
# tar -czvf -9 archive.tar.gz files...
# !tar -czvf -9 ../ensemble_dmifgsm.tar.gz
# %cd ..
# %pwd
# Out:
# /home/wmnlab/Documents/sheng-ru/bai/test2/ensemble_mifgsm
# airplane/
# airplane/airplane7.png
# airplane/airplane4.png
# airplane/airplane1.png
# airplane/airplane10.png
# airplane/airplane17.png
# airplane/airplane5.png
# airplane/airplane2.png
# airplane/airplane8.png
# airplane/airplane20.png
# airplane/airplane14.png
# airplane/airplane9.png
# airplane/airplane19.png
# airplane/airplane16.png
# airplane/airplane3.png
# airplane/airplane12.png
# airplane/airplane18.png
# airplane/airplane11.png
# airplane/airplane6.png
# airplane/airplane15.png
# airplane/airplane13.png
# automobile/
# automobile/automobile12.png
# automobile/automobile18.png
# automobile/automobile6.png
# automobile/automobile5.png
# automobile/automobile7.png
# automobile/automobile14.png
# automobile/automobile10.png
# automobile/automobile2.png
# automobile/automobile15.png
# automobile/automobile9.png
# automobile/automobile3.png
# automobile/automobile20.png
# automobile/automobile11.png
# automobile/automobile8.png
# automobile/automobile19.png
# automobile/automobile17.png
# automobile/automobile16.png
# automobile/automobile1.png
# automobile/automobile13.png
# automobile/automobile4.png
# bird/
# bird/bird13.png
# bird/bird6.png
# bird/bird8.png
# bird/bird1.png
# bird/bird2.png
# bird/bird19.png
# bird/bird14.png
# bird/bird5.png
# bird/bird7.png
# bird/bird15.png
# bird/bird12.png
# bird/bird9.png
# bird/bird3.png
# bird/bird11.png
# bird/bird17.png
# bird/bird4.png
# bird/bird20.png
# bird/bird16.png
# bird/bird10.png
# bird/bird18.png
# cat/
# cat/cat7.png
# cat/cat1.png
# cat/cat10.png
# cat/cat5.png
# cat/cat9.png
# cat/cat17.png
# cat/cat13.png
# cat/cat8.png
# cat/cat20.png
# cat/cat18.png
# cat/cat3.png
# cat/cat15.png
# cat/cat14.png
# cat/cat19.png
# cat/cat2.png
# cat/cat16.png
# cat/cat12.png
# cat/cat11.png
# cat/cat6.png
# cat/cat4.png
# deer/
# deer/deer10.png
# deer/deer17.png
# deer/deer4.png
# deer/deer16.png
# deer/deer6.png
# deer/deer9.png
# deer/deer20.png
# deer/deer15.png
# deer/deer12.png
# deer/deer19.png
# deer/deer3.png
# deer/deer7.png
# deer/deer1.png
# deer/deer11.png
# deer/deer14.png
# deer/deer13.png
# deer/deer5.png
# deer/deer18.png
# deer/deer8.png
# deer/deer2.png
# dog/
# dog/dog19.png
# dog/dog13.png
# dog/dog11.png
# dog/dog5.png
# dog/dog1.png
# dog/dog2.png
# dog/dog17.png
# dog/dog4.png
# dog/dog10.png
# dog/dog8.png
# dog/dog12.png
# dog/dog18.png
# dog/dog6.png
# dog/dog14.png
# dog/dog9.png
# dog/dog15.png
# dog/dog7.png
# dog/dog16.png
# dog/dog3.png
# dog/dog20.png
# frog/
# frog/frog7.png
# frog/frog20.png
# frog/frog18.png
# frog/frog16.png
# frog/frog14.png
# frog/frog8.png
# frog/frog4.png
# frog/frog2.png
# frog/frog12.png
# frog/frog5.png
# frog/frog10.png
# frog/frog13.png
# frog/frog17.png
# frog/frog9.png
# frog/frog11.png
# frog/frog1.png
# frog/frog6.png
# frog/frog3.png
# frog/frog19.png
# frog/frog15.png
# horse/
# horse/horse7.png
# horse/horse6.png
# horse/horse4.png
# horse/horse13.png
# horse/horse12.png
# horse/horse14.png
# horse/horse8.png
# horse/horse20.png
# horse/horse2.png
# horse/horse9.png
# horse/horse17.png
# horse/horse16.png
# horse/horse1.png
# horse/horse5.png
# horse/horse11.png
# horse/horse3.png
# horse/horse19.png
# horse/horse10.png
# horse/horse18.png
# horse/horse15.png
# ship/
# ship/ship20.png
# ship/ship3.png
# ship/ship14.png
# ship/ship8.png
# ship/ship16.png
# ship/ship1.png
# ship/ship11.png
# ship/ship7.png
# ship/ship2.png
# ship/ship5.png
# ship/ship19.png
# ship/ship17.png
# ship/ship10.png
# ship/ship18.png
# ship/ship9.png
# ship/ship4.png
# ship/ship15.png
# ship/ship13.png
# ship/ship12.png
# ship/ship6.png
# truck/
# truck/truck2.png
# truck/truck20.png
# truck/truck1.png
# truck/truck9.png
# truck/truck12.png
# truck/truck17.png
# truck/truck3.png
# truck/truck14.png
# truck/truck19.png
# truck/truck11.png
# truck/truck13.png
# truck/truck8.png
# truck/truck16.png
# truck/truck18.png
# truck/truck6.png
# truck/truck4.png
# truck/truck7.png
# truck/truck15.png
# truck/truck5.png
# truck/truck10.png
# /home/wmnlab/Documents/sheng-ru/bai/test2

# %%
# from google.colab import files
# files.download('ensemble_dmifgsm.tgz')
# files.download('ensemble_mifgsm.tgz')
# files.download('ensemble_ifgsm.tgz')

# %% [markdown]
# ## Visualization

# %%
# %pwd

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'/home/wmnlab/Documents/sheng-ru/bai/test2/data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./fgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Report Question
# * Make sure you follow below setup: the source model is "resnet110_cifar10", applying the vanilla fgsm attack on `dog2.png`. You can find the perturbed image in `fgsm/dog2.png`.

# %%
# original image
path = f'dog/dog2.png'
im = Image.open(f'./data/{path}')
logit = model(transform(im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'benign: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# adversarial image 
adv_im = Image.open(f'./fgsm/{path}')
logit = model(transform(adv_im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(adv_im))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Passive Defense - JPEG compression
# JPEG compression by imgaug package, compression rate set to 70
#
# Reference: https://imgaug.readthedocs.io/en/latest/source/api_augmenters_arithmetic.html#imgaug.augmenters.arithmetic.JpegCompression
#
# Note: If you haven't implemented the JPEG compression, this module will return an error. Don't worry about this.

# %%
import imgaug.augmenters as iaa

# pre-process image
x = transforms.ToTensor()(adv_im)*255
x = x.permute(1, 2, 0).numpy()
x = x.astype(np.uint8)

# TODO: use "imgaug" package to perform JPEG compression (compression rate = 70)
compressed_x =  iaa.arithmetic.compress_jpeg(x, compression=70)

logit = model(transform(compressed_x).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'JPEG adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')


plt.imshow(compressed_x)
plt.tight_layout()
plt.show()
